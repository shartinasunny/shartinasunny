# %% [markdown]
# # CASE STUDY ON ANOVA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

datafile='Sales_data_zone_wise.csv'

data=pd.read_csv(r"C:\Users\Admin\Downloads\\Sales_data_zone_wise.csv")

print (data)
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %% [markdown]
# # THE MEAN SALES GENERATED BY EACH ZONE

# %%
data.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %%
print('Mean of Zone - A:', data['Zone - A'].mean())
print('Mean of Zone - B:', data['Zone - B'].mean())
print('Mean of Zone - C:', data['Zone - C'].mean())
print('Mean of Zone - D:', data['Zone - D'].mean())
# Out:
# Mean of Zone - A: 1540493.1379310344
# Mean of Zone - B: 1755559.5862068965
# Mean of Zone - C: 1772871.0344827587
# Mean of Zone - D: 1842926.7586206896

# %% [markdown]
# # Inference
#          Here Zone - D has the highest mean and Zone - A has the lowest mean . Also we note that Zone - B has the lowest standard deviation , which means the sales by Zone - B is the most consistent.

# %%
def sum_frame_by_column(frame, list_of_cols_to_sum, new_col_name):
    frame[new_col_name] = frame[list_of_cols_to_sum].astype(float).sum(axis=1)
    return(frame)
sum_frame_by_column(data, ['Zone - A','Zone - B','Zone - C','Zone - C','Zone - D'],'Total_sales')
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  Total_sales
# 0    Month - 1   1483525   1748451   1523308   2267260    8545852.0
# 1    Month - 2   1238428   1707421   2212113   1994341    9364416.0
# 2    Month - 3   1860771   2091194   1282374   1241600    7758313.0
# 3    Month - 4   1871571   1759617   2290580   2252681   10465029.0
# 4    Month - 5   1244922   1606010   1818334   1326062    7813662.0
# 5    Month - 6   1534390   1573128   1751825   2292044    8903212.0
# 6    Month - 7   1820196   1992031   1786826   1688055    9073934.0
# 7    Month - 8   1625696   1665534   2161754   2363315    9978053.0
# 8    Month - 9   1652644   1873402   1755290   1422059    8458685.0
# 9   Month - 10   1852450   1913059   1754314   1608387    8882524.0
# 10  Month - 11   2004480   1740365   1317869   1970069    8350652.0
# 11  Month - 12   1537539   1875658   1237722   1460165    7348806.0
# 12  Month - 13   1254939   1588473   1348629   1733383    7274053.0
# ...

# %% [markdown]
# # Insight
#           In the above given data the last column total_sales represents the total sales by  in each month.From the above data Month 4 had the highest sales and Month 13 had the lowest sales

# %% [markdown]
# # Checking whether all the zones generated the same amount of sales

# %%
import scipy.stats as stats
stats.f_oneway(data['Zone - A'],data['Zone - B'],data['Zone - C'],data['Zone - D'])
# Out:
# F_onewayResult(statistic=5.672056106843581, pvalue=0.0011827601694503335)

# %% [markdown]
# Null hypothesis : All the zones generate the same amount of sales .
# Alternate hypothesis: All the zones generate different amount of sales .

# %% [markdown]
# # Conclusion

# %% [markdown]
# Since the p value is very small we reject the null hypothesis and conclude that all the zones generate different amount of  sales .
